# %% [markdown]
# # Art of Proof - Matthias Beck and Ross Geoghegan
#
# ## Integers, $Z$
#
# ### Axioms and Propositions
#
# **Axiom 1.1.** If m, n, and p are integers, then
#
# (i) $m+n = n +m$ (commutativity of addition)
#
# (ii) $(m+n) + p = m+(n + p)$ (associativity of addition)
#
# (iii) $m. (n + p) = m. n +m . p$ (distributivity)
#
# (iv) $m. n = n . m$ (commutativity of multiplication)
#
# (v) $(m . n) . p = m. (n . p)$ (associativity of multiplication)
#
# **Axiom 1.2.** There exists an integer $0$ such that whenever $m \in Z, m+0 = m$. (identity element for addition)
#
# **Axiom 1.3.** There exists an integer $1$ such that $1 \ne 0$ and whenever $m \in Z, m . 1 = m$. (identity element for multiplication)
#
# **Axiom 1.4.** For each $m \in Z$, there exists an integer, denoted by $m$, such that $m+(-m) = 0$. (additive inverse)
#
# **Axiom 1.5.** Let $m, n$, and $p$ be integers. If $m . n = m . p$ and $m \ne 0$, then $n = p$. (cancellation)
#
# **Proposition 1.6**. If $m, n$, and $p$ are integers, then $(m+n)p = mp + np$
#
# **Proposition 1.7**. If $m$ is an integer, then $0 + m = m$ and $1 . m = m$.
#
# **Proposition 1.8**. If $m$ is an integer, then $(-m) +m = 0$.
#
# **Proposition 1.9**. Let $m, n$, and $p$ be integers. If $m+n = m+ p$, then $n = p$.
#
# **Proposition 1.10**. Let $m, x{_1}, x{_2} \in Z$. If $m, x{_1}, x{_2}$ satisfy the equation $ m + x{_1} = 0 $ and $m + x{_2} = 0$, then $x{_1} = x{_2}$
#
# **Proposition 1.11**. If $m, n, p$, and $q$ are integers, then
#
# (i) $(m+n)(p +q) = (mp + np) + (mq + nq)$.
#
# (ii) $m+(n +(p +q)) = (m+n) +(p +q) = ((m+n) + p) +q$.
#
# (iii) $m + (n + p) = (p +m) + n$.
#
# (iv) $m(np) = p(mn)$.
#
# (v) $m(n +(p +q)) = (mn + mp) + mq$.
#
# (vi) $(m(n + p)) q = (mn)q + m(pq)$.
#
# **Proposition 1.12**. Let $x \in Z$. If x has the property that for each integer $m, m+x = m$,
# then $x = 0$.
#
# **Proposition 1.13**. Let $x \in Z$. If $x$ has the property that there exists an integer $m$ such that $m+x = m$, then $x = 0$.
#
# **Proposition 1.14**. For all $m \in Z$, $m . 0 = 0 = 0 . m$.
#
# **Proposition 1.16**. If $m$ and $n$ are even integers, then so are $m+n$ and $mn$.
#
# **Proposition 1.17**.
#
# (i) $0$ is divisible by every integer.
#
# (ii) If $m$ is an integer not equal to $0$, then $m$ is not divisible by 0.
#
# **Proposition 1.18**. Let $x \in Z$. If x has the property that for all $m \in Z$, $mx = m$, then $x = 1$.
#
# **Proposition 1.19**. Let $x \in Z$. If $x$ has the property that for some nonzero $m \in Z, mx = m$, then $x = 1$.
#
# **Proposition 1.20**. For all $m, n \in Z, (-m)(-n) = mn$.
#
# **Corollary 1.21**. (-1)(-1) = 1.
#
# **Proposition 1.22**
#
# (i) For all $m \in Z, -(-m) = m$.
#
# (ii) $-0 = 0$.
#
# **Proposition 1.23**. Given $m, n \in Z$ there exists **one and only one** $x \in Z$ such that $m+x = n$.
#
#
# **Proposition 1.24**. Let $x \in Z$. If $x . x = x$ then $x = 0$ or $1$.
#
# **Proposition 1.25**. For all $m, n \in Z$:
#
# (i) $-(m+n) = (-m) +(-n)$.
#
# (ii) $-m = (-1)m$.
#
# (iii) $(-m)n = m(-n) = -(mn)$.
#
# **Proposition 1.26**. Let $m, n \in Z$. If $mn = 0$, then $m = 0$ or $n = 0$.
#
# **Proposition 1.27**. For all $m, n, p, q \in Z$
#
# (i) $(m-n) +(p-q) = (m+ p)-(n +q)$.
#
# (ii) $(m-n)-(p-q) = (m+q)-(n + p)$.
#
# (iii) $(m-n)(p-q) = (mp +nq)-(mq+np)$.
#
# (iv) $m-n = p-q$ if and only if $m+q = n + p$.
#
# (v) $(m-n)p = mp-np$.
#
# ### Properties of $"="$
#
# (i) $m = m$ (reﬂexivity)
#
# (ii) If $m = n$ then $n = m$ (symmetry)
#
# (iii) If $m = n$ and $n = p$ then $m = p$ (transitivity)
#
# (iv) If m = n, then n can be substituted for m in any statement without changing the meaning of that statement. (replacement)
#
# An example of (iv): If we know that $m = n$ then we can conclude that $m + p = n + p$. The symbol $“=”$ means **is not equal to**. To say $m = n$ means $m$ and $n$ are different numbers. Note that $“=”$ satisﬁes symmetry, but not transitivity and reﬂexivity. Similarly, the symbol $\notin $ means **is not an element of**.
#
# ## How to approach "$if \heartsuit$ then $\clubsuit$" proofs
#
# Begin by assuming $\heartsuit$, then go to $\heartsuit \prime$, then $\heartsuit \prime \prime$.
#
# The last step is to get to $\clubsuit$
#
# ### 'OR' in mathematics
# This is so important that we will say it again: In mathematics, $\heartsuit$ or $\clubsuit$ always
# means either $\heartsuit$ or $\clubsuit$, or both $\heartsuit$ and $\clubsuit$
#
# ## The phrase "if and only if"
#
# It refers to two if-then statements. $\heartsuit$ if and only if $\clubsuit$ means if $\heartsuit$ then $\clubsuit$ and if $\clubsuit$ then $\heartsuit$
#
# ## Natural Numbers, $N$ and Induction
#
# The members of $N$ are called natural numbers or positive integers
#
# ### Axioms and Propositions
#
# **Axiom 2.1**. There exists a subset $N \subseteq Z$ with the following properties:
#
# (i) If $m, n \in N$ then $m+n \in N$.
#
# (ii) If $m, n \in N$ then $mn \in N$.
#
# (iii) $0 \notin N$.
#
# (iv) For every $m \in Z$, we have $m \in N$ or $m = 0$ or $-m \in N$.
#
# Note on axiom 2.1 (iv) === the -m in N applies to situations where a member of Z is negative, in that case -(-m) would be +ve and thus a member of N. The 'or' is used in an 'exclusive' sense.
#
# **Proposition 2.2**. For $m \in Z$, one and only one of the following is true: $m \in N, -m \in N, m = 0$.
#
# **Proposition 2.3**. $1 \in N$.
#
# proof:
#
# Assume: $1 \notin N$
#
# P2.2: $1 = 0$ (P2.2 says that the only thing that does not belong to $N$ is one)
#
# But: $1 \ne 0$ Thus our proposition is proved
#
#
# ### Template for Proof by Contradiction
# To prove that $\heartsuit$ is true. Suppose (by way of contradiction) that $\heartsuit$ is false. Deduce from this, in as many steps as necessary that $\spadesuit$ is true, where $\spadesuit$ is a statement you know to be false. Conclude that$\heartsuit$ is true, because the supposition that $\heartsuit$ is false led to a contradiction.
#
# ### Ordering Integers
#
# Now that we have introduced N, we can order the integers. Here is how we do it:
#
# Let $m, n \in Z$. The statements $m < n$ (m is less than n) and $n > m$ (n is greater than m) both **mean that** $n− m \in N$
#
# The notations $m \le n$ (m is less than or equal to n) and $n \ge m$ (n is greater than or equal to m) **mean that** $m < n$ or $m = n$:
#
# **Proposition 2.4**. Let $m, n, p \in Z$. If $m < n$ and $n < p$ then $m < p$.
#
# *Say*, $m-n \in N$ and $p-n \in N$
#
# *A2.1(i)* $(n-m) + (p-n) \in N$
#
# *i.e*, $p-m \in N$
#
# *thus* $p>m$ or $m<p$ $\square$
#
# **Proposition 2.5**. For each $n \in N$ there exists $m \in N$ such that $m > n$.
#
# **Proposition 2.6**. Let $m, n \in Z$. If $m \le n \le m$ then $m = n$.
#
# $m \le n \implies m-n \in N$
#
# $n \le m \implies n-m \in N$
#
# $m < n$ contradicts $n < m$ and vice versa
#
# $m = n$ is the only option left $\square$
#
#
#
#
# **Proposition 2.7**. Let $m, n, p, q \in Z$.
#
# (i) If $m < n$ then $m+ p < n+ p$.
#
# (ii) If $m < n$ and $p < q$ then $m+ p < n+ q$.
#
# (iii) If $0 < m < n$ and $0 < p \le q$ then $mp < nq$.
#
# (iv) If $m < n$ and $p < 0$ then $np < mp$.
#
# **Proposition 2.8**. Let $m, n \in Z$. Exactly one of the following is true: $m < n, m = n,
# m > n$
#
# **Proposition 2.9**. Let $m \in Z$. If $m \ne 0$ then m^2 \in N. Here m^2 means m·m.
#
# **Proposition 2.10**. The equation $x^2 = −1$ has no solution in $Z$. Proposition 2.10 is an
#
# *Given* $x^2 = -1$
#
# *Assume* $x \in Z$
#
# *P2.9* ($x^2 \in N) (\forall x \in Z$) except $x=0$
#
# *But* $x^2 = -1$ and $-1\notin N$
# $\square$
#
#
#
# **Proposition 2.11**. Let $m \in N$ and $n \in Z$. If $mn \in N$, then $n \in N$.
#
# **Proposition 2.12**. For all $m, n, p \in Z$:
#
# (i) $−m < −n$ if and only if $m > n$.
#
# (ii) If $p > 0$ and $mp < np$ then $m < n$.
#
# (iii) If $p < 0$ and $mp < np$ then $n < m$.
#
# (iv) If $m \le n$ and $0 \le p$ then $mp \le np$.
#
# **Proposition 2.13**. $N = \{n \in Z : n > 0\}$:
#
#
#
#
# ## Induction
#
# **My understanding**
#
# Define a set ($B \subseteq N$), in this case ($1, n, n+1$)
#
# show that $P(k)$ is true ($\forall n \in B$)
#
# Then *P2.16* says that $B = N$, which means that $P(k)$ must be true $\forall k \in N$
#
# **Proposition 2.14**.
#
# (i) $1 \in N$.
#
# (ii) If $n \in N$ then $n+ 1 \in N$.
#
# **Axiom 2.15 (Induction Axiom)**. If a subset $A \subseteq Z$ satisfies
#
# (i) $1 \in A$ and
#
# (ii) if $n \in A$ then $n+ 1 \in A$,
#
# then $N \subseteq A$
#
# This axiom essentially says that the smallest subset of $Z$ that satisfies P2.14 is the set $N$
#
#
# **Proposition 2.16**. Let $B \subseteq N$ be such that:
#
# (i) $1 \in B$ and
#
# (ii) if $n \in B$ then $n+ 1 \in B$.
#
# Then $B = N$
#
# **Theorem 2.17 (Principle of mathematical induction—first form)**. Let $P(k)$ be a statement depending on a variable $k \in N$. In order to prove the statement “$P(k)$ is true for all $k \in N$” it is sufficient to prove:
#
# (i) $P(1)$ is true and
#
# (ii) for any given $n \in N$, if $P(n)$ is true then $P(n+ 1)$ is true.
#
# The notation $S := \heartsuit$ means we are defining S to be $\heartsuit$
#
# Proof:
#
# *Definition*: $B := \{k \in N: P(k)$ is true$\}$ i.e. B is a set containing values of $N$ for with the function $P(k)$ holds true.
#
# *Assume*: (i) we can prove $P(1)$ true and
#
# (ii)if $P(n)$ is true, then $P(n + 1)$ is true
#
# *That means*: $1 \in B$; and if $n \in B$, then, $n + 1 \in B$
#
# *P2.16*: $B = N$ $\square$
#
# **Proposition 2.18**.
#
# (i) For all $k \in N, k^3 + 2k$ is divisible by $3$.
#
# (ii) For all $k \in N, k^4 − 6k^3 + 11k^2 − 6k$ is divisible by $4$.
#
# (iii) For all $k \in N, k^3 + 5k$ is divisible by $6$
#
# **Project 2.19**. Come up with (and prove) other divisibility statements.
#
# **Proposition 2.20**. For all $k \in  N, k \ge 1$.
#
# **Proposition 2.21**. There exists no integer $x$ such that $0 < x < 1$.
#
# **Corollary 2.22**. Let $n \in Z$. There exists no integer $x$ such that $n < x < n + 1$.
#
# **Proposition 2.23**. Let $m, n \in  N$. If $n$ is divisible by $m$ then $m ≤ n$.
#
# **Proposition 2.24**. For all $k \in  N, k^2 + 1 > k$
#
# **Theorem 2.25 (Principle of mathematical induction—first form revisited)**. Let $P(k)$ be a statement, depending on a variable $k \in Z$, that makes sense for all $k \ge m$, where $m$ is a fixed integer. In order to prove the statement “$P(k)$ is true for all $k \ge m$”, it is sufficient to prove:
#
# (i) $P(m)$ is true and
#
# (ii) for any given $n \ge m$, if $P(n)$ is true then $P(n + 1)$ is true.
#
# **Proposition 2.26**. For all integers $k \ge −3$, $3k^2 + 21k + 37 \ge 0$.
#
# **Proposition 2.27**. For all integers $k \ge 2, k^2 < k^3$
#
# **Project 2.28**. Determine for which natural numbers $k^2 - 3k \ge 4$ and prove your answer.
#
# $k^2 - 3k - 4 \ge 0$
#
# $(k - 4)(k + 1) \ge 0$
#
# $\therefore k = 4$ or $k = -1$
#
# since $k$ is a natural number, we choose $k = 4$
#
#
# ### The Well-Ordering Principle
#
# Let $A \subseteq Z$ be nonempty. If there exists $b \in A$ such that for all $a \in A, b \le a$, then $b$ is the **smallest element** of $A$, in which case we write $b = min(A)$.
#
# i.e. $(\exists b \in A)(\forall a \in Z)(b \le a)$
#
# **Project 2.31**. What is the smallest element of $\{3m+8n : m, n \in Z, m \ge n \ge -4\}$?
#
# **Solution** Since $m, n$ are integers whose minimum values are each $4$, then the smallest value is $3.m + 8.n = 3.4 + 8.4 = 12 + 32 = 44$
#
# **Theorem 2.32 (Well-Ordering Principle)**. Every nonempty subset of N has a smallest element.
#
# **Proposition 2.33**. Let A be a nonempty subset of Z and $b \in Z$, such that for each $a \in A, b \le a$. Then A has a smallest element
#
# **Proposition 2.34**. If $m$ and $n$ are integers that are not both $0$, then
#
# $S = \{k \in N : k = mx + ny$ for some $x, y \in Z\}$
#
# is not empty. The smallest element of $S$ is defined to be the $\gcd(m, n)$. We only take those values of the set $S$ that belong to $N$
#
# **Project 2.35**. Compute $\gcd(4, 6)$, $\gcd(7, 13)$, $\gcd(4, 10)$, and $\gcd(5, 15)$
#
# **Project 2.36**. Given a nonzero integer $n$, compute $\gcd(0, n)$ and $\gcd(1, n)$.
#
# ## Quantifiers
#
# **Project 3.1**. Express each of the following statements using quantifiers.
#
# (i) There exists a smallest natural number. $(\exists n \in N)(n = \min (N))$
#
# (ii) There exists no smallest integer. $(\nexists n \in Z)(n = \min (Z))$
#
# (iii) Every integer is the product of two integers. $(\forall n, x, y \in Z) (n = x.y)$
#
# (iv) The equation $x^2 − 2y^2 = 3$ has an integer solution. $(\exists x, y \in Z)(x^2 − 2y^2 = 3)$
#
# **Project 3.2**. In each of the following cases explain what is meant by the statement and decide whether it is true or false.
#
# (i) For each $x \in Z$ there exists $y \in Z$ such that $x + y = 1$.
#
# (ii) There exists $y \in Z$ such that for each $x \in Z, x + y = 1$.
#
# **(i) and (ii) are trying to say the same thing but (i) is wrong while (ii) is right**
#
# (iii) For each $x \in Z$ there exists $y \in Z$ such that $xy = x$.
#
# (iv) There exists $y \in Z$ such that for each $x \in Z, xy = x$.
#
# **(iii) and (iv) are trying to say the same thing but (iv) is wrong while (iii) is right**
#
# $\heartsuit \implies \spadesuit$ Implication
#
# $\spadesuit \implies \heartsuit$ Converse
#
# not $\spadesuit \implies$ not $\heartsuit$ Contrapositive
#
#
# **Project 3.3**. Construct two more mathematical if–then statements that are true, but whose converses are false.
#
# **Project 3.5**. Re-prove some of the if–then propositions in Chapters 1 and 2 by
# proving their contrapositives.
#
# **Project 3.7**. Negate the following statements.
#
# (i) Every cubic polynomial has a real root.
#
# **ans** It is not the case that every cubic polynomial has a real root.
#
# (ii)$G$ is normal and $H$ is regular.
#
# **and** either $G$ is not normal or $H$ is not regular
#
# (iii) $\exists! 0$ such that $ \forall x, x + 0 = x$.
#
# (iv) The newspaper article was neither accurate nor entertaining.
#
# (v) If $\gcd(m; n)$ is odd, then m or n is odd.
#
# (vi) $H/N$ is a normal subgroup of $G/N$ if and only if $H$ is a normal subgroup of $G$.
#
# (vii) For each $\epsilon > 0$ there exists $N \in N$ such that for all $n \ge N,|{a_n - L}| < \epsilon$
#
# Negation of $\exists !$
#
# Exists and is unique - Thus the negation will be "does not exist or even if it does exist, its not unique"
#
# Negation of an "if-then" statement
#
# $\neg (\heartsuit \implies \clubsuit) = (\heartsuit \wedge \neg \clubsuit)$
#
# (iii)Problem can be stated thus:
#
# There exist a unique element ,0, such that for all $x, x + 0 = x$ or
#
# There exist an element such that $x + 0 = x$, and that element is unique and is called 0
#
# But the second form is better in that it separates *uniqueness* from *existence*
#
# **form 1**
#
# Problem: $\exists ! 0: (\forall x)x + 0 = x$
#
# Translates to $\exists 0 : (\forall x)(x + 0 = x) \wedge 0 = !$
#
# Negation: $(\forall 0) (\exists x : x + 0 \ne x) \vee 0 \ne !$ - Either there is an $x$ (at least one) for which $x + 0 \ne x$ or $0$ is not unique
#
#
# **Form 2: replace 0 with y**
#
# Problem: $(\exists y: x + y = x) \wedge y = !$
#
# Negation: $(\forall x, x + y \ne y) \vee y \ne !$
#
#
#
#
# (v) If $\gcd(m, n)$ is odd, then ($m$ is odd) $\vee$ ($n$ is odd)
#
#
# $\gcd(m,n)$ is odd $\wedge$ ($m$ is not odd) $\wedge$ ($n$ is not odd)
#
# ### Recursion
#
#
# ```python
# def evenn(n):
#     if n%2 == 0:
#         return True
#     return False
#
# def threex(m, k):
#     listin = [m]
#     for i in range(1, k):
#         if evenn(listin[i-1]):
#             listin.append(listin[i-1]/2)
#         else:
#             listin.append(listin[i-1] + 1)
#
#     return listin
#
# threex(20, 100000)
# ```
#
#
#
# **Project 4.3**. (“$x + 1$ problem”): Pick your favorite natural number m, and define the following sequence:
#
# (i) Define $x_1 := m$.
#
# (ii) Assuming $x_n$ defined, define $x_{n+1} := \begin{cases}
# \frac{x_n}{2} & \text{if $x_n$ is even} \\
# x_n + 1 & \text{if $x_n$ is odd}
# \end{cases}$
#
# Does this sequence eventually take on the value 1, no matter what $m \in N$ one chooses as the starting point? Try to prove your assertion.
#
# Yes. It eventually takes the value 1.
#
# Looking at the definition of $x_{n+1}$, we see that the definition of $x_{n+1}$ when $x_n$ is odd resets the value of $x_n$ to an even number, which is subsequently split in half by the definition of $x_{n+1}$ when $x_n$ is even. Eventually, the value of $x_n$ reduces continuously till it gets to one no matter what m we start out with.
#
#
#
# **Theorem 4.4**. A legitimate method of describing a sequence $(y_j)_{j=m}^\infty$ is:
#
# (i) to name $y_m$ and
#
# Power. Let b be a fixed integer. We define bk for all integers k ≥ 0 by:
# (i) b0 := 1.
# (ii) Assuming bn defined, let bn+1 := bn ·b.(ii) to state a formula describing $y_{n+1}$ in terms of $y_n$, for each $n \ge m$.
#
# **Power**. Let b be a fixed integer. We define $b^k$ for all integers $k ≥ 0$ by:
#
# (i) $b^0 := 1$.
#
# (ii) Assuming $b^n$ defined, let $b^{n+1} := b^n ·b$.
#
#
# **Proposition 4.5**. For all $k \in Z≥0, k! \in N$
#
# **Proposition 4.6**. Let $b \in Z$ and $k, m \in Z_{\ge 0}$.
#
# (i) If $b \in N$ then $b^k \in N$.
#
# (ii) $b^m b^k = b^{m+k}$.
#
# (iii) $(b^m)^k = b^{mk}$.
#
# **Proposition 4.7**. For all $k \in N$:
#
# (i) $5^{2k} − 1$ is divisible by 24;
#
# (ii) $2^{2k+1} + 1$ is divisible by 3;
#
# (iii) $10^k + 3· 4^{k+2} + 5$ is divisible by 9.
#
# **Proposition 4.8**. For all $k \in N, 4^k > k$
#
# **Proof of 4.7 (i)**
#
# Say $P(k): 5^{2k} − 1$ is divisible by 24
#
# $P(0): 5^{2.0} − 1 = 0$. This is divisible by 24
#
# $P(n): 5^{2n} − 1$ is divisible by 24 to be true
#
# Let $\frac {5^{2n} - 1}{24} = r$ where $r \in N$
#
# Gives: $5^{2n} = 24r + 1$
#
#
# $P(n+1): 5^{2(n+1)} − 1 = 5^{2n}.5^2 - 1 = 25.5^{2n} - 1$
#
# Let $\frac{25.5^{2n} - 1}{24} = q$ where $q \in N$
#
# Thus, $25.5^{2n} - 1 = 24q$
#
#
# Substitute for $5^{2n}$ into the expression for $P(n+1)$
#
# We have, $25(24r + 1) - 1 = 24q$
#
# Simplify: $25.24r + 25 - 1 = 24q\\ 25.24r + 24 = 24q\\ 25r + 1 = q$
#
# Since $r \in N$, it follows necessarily that $q \in N$ $\square$
#
#
#
# **Project 4.9**. Determine for which natural numbers $k^2 < 2^k$ and prove your answer
#
# **Project 4.10**. Come up with a recursive deﬁnition of the sum $\sum _{j=m}^{n}x_j$ for two integers $m \le n$.
#
# **Solution to 4.10**
#
# Define $\sum_{j=m}^{m}x_j$ to be $x_m$
#
# Assuming $\sum_{j=m}^{(n-1)}x_j$ to be defined already
#
# Then, $\sum_{j=m}^{n}x_j = (\sum_{j=m}^{n-1}x_j) + x_{n-1}$
#
# ### Finite Series
#
# Sequences defined as sums are called **finite series**
#
# **Proposition 4.11**. Let $k \in N$
#
# (i) $\sum_{j=1}^{k}j = \frac{k(k+1)}{2}$
#
# (ii) $\sum_{j=1}^{k}j^2 = \frac{k(k+1)(2k+1)}{6}$
#
# **Project 4.12**. Find (and prove) a formula for $\sum_{j=1}^{k}j^3$
#
# **Proposition 4.13**. For $x \ne 1$ and $k \in Z_{\ge 0}, \sum_{j=0}^{k}x^j = \frac{1-x^{k+1}}{1-x}$
#
# **Project 4.14**. With calculus, Proposition 4.13 can be used to generate formulas for $\sum_{j=0}{k}j^m$ for $m = 1, 2, 3, 4,\dots$, similar to those found in Proposition 4.11 and Project 4.12. Think about how this could be done.
#
# **Proposition 4.15**
#
# (i) Let $m \in Z$ and let $(x_j)_{j=1}^{\infty}$ be a sequence in $Z$. Then for all $k \in N\\ m.(\sum_{j=1}^{k}x_j) = \sum_{j=1}^{k}mx_j$
#
# (ii) If $x_j = 1$ for all $j \in N$ then for all $k \in N\\ \sum_{j=1}^{k}x_j = k$
#
# (iii) If $x_j = n \in Z$ for all $j \in N$, then for all $k \in N\\ \sum_{j=1}^{k}x_j = kn$
#
# **Proposition 4.16** Let $(x_j)_{j=1}^{\infty}$ be a  sequences in $Z$, and let $a, b, c, \in Z$ be such that $a \le b < c$.
#
# (i)$\sum_{j=a}^{c} = \sum_{j=a}^{b} + \sum_{j=b+1}^{c}$
#
# (ii)$\sum_{j=a}^{b}(x_j+y_j) = \sum_{j=a}^{b}x_j + \sum_{j=a}^{b}y_j$
#
# **Proposition 4.17** Let $(x_j)_{j=1}^{\infty}$ be a sequence in $Z$ and let $a, b, r \in Z$ such that $a \le b$. Then $\sum_{j=a}^{b}x_j = \sum_{j=a+r}^{b+r}x_{j-r}$
#
# **Proposition 4.18** Let $(x_j)_{j=1}^{\infty}$ be a sequence in $Z$ such that $x_j \le y_j$ for all $j \in N$. Then for all $k \in N\\ \sum_{j=1}^{k}x_j \le \sum_{j=1}^{k}y_j$
#
# **Theorem 4.19**. Let $k, m \in Z_{≥0}$, where $m \le k$. Then $m!(k− m)!$ divides $k!$.
#
# **Proof**
#
# For each $k \in Z_{\ge0}$,we write a statement $P(k)$ that we are to use for our induction
#
# $P(k): (\forall 0 \le m \le k )(\exists j \in Z):(k! = jm!(k-m)!)$
#
# We need to proof $P(0)$ and $P(n) \implies P(n+1)$
#
# $P(0): (\forall 0 \le m \le 0)\\ 0! = j.0!(0-0)!\\ 0! = j.0!.0!\\ \therefore j \in Z$
#
# $P(n) \implies P(n+1) \\ (\forall 0 \le m \le n+1)\\ (n+1)! = j.m!(n+1-m)!$
#
# At this stage we have the following cases $0, 1 \le m \le n, n+1$
#
# $m = 0; (n+1)! = j.0!.(n+1-0)! = j0!(n+1)!\\ m = n+1; (n+1)! = j(n+1)!(n+1-(n+1))! = j(n+1)!0!$
#
# In both cases, $j \in Z$
#
# Now for any particular $m \in (1 \le m \le n)$,
#
# To be continued
#
# **Corollary 4.20**. For $1 \le m \le k, \binom{k + 1}{m} = \binom{k}{m - 1} + \binom{k}{m}$
#
# This gives the binomial coefficients
#
# We could rewrite it as
#
# $\binom{row + 1}{col} = \binom{row}{col - 1} + \binom{row}{col}\\ \binom{row}{col} = \binom{row-1}{col - 1} + \binom{row-1}{col}$
#
# **Theorem 4.21 (Binomial theorem for integers)**. If $a, b \in Z$ and $k \in Z_{≥0}$ then
#
# $(a+b)^k = \sum_{m=0}^{k}\binom{k}{m}a^m b^{k-m}$
#
# **Corollary 4.22** For $k \in Z_{≥0},\\ \sum_{m=0}^{k}\binom{k}{m} = 2^k$
#
# **Project 4.23 (Leibniz’s formula)** Consider an operation denoted by $^\prime$ that is applied to symbols such as u, v, w. Assume that the operation $^\prime$ satisfies the following axioms:
#
# $(u + v)^\prime = u^\prime + v^\prime \\ (uv)^\prime = uv^\prime + u^\prime v\\ (cu)^\prime = cu^\prime$
#
# Define $w^{k}$ recursively by
#
# (i) $w^{0} := w$
#
# (ii) Assuming $w^{n}$ defined (where $n \in Z_{\ge0}$), define $w^{(n+1)} := {(w^{n})}^\prime$
#
# Proof $(uv)^{k} = \sum_{m=0}^{k}\binom{k}{m}u^m v^{k-m}$
#
# **Solution**
#
# $P(k):(uv)^{k} = \sum_{m=0}^{k}\binom{k}{m}u^m v^{k-m}$
#
# $P(0): \text { base case}$
#
# $(uv)^{0}$ $= \sum_{m=0}^{0}\binom{0}{m}u^m v^{0-m}\\ = \binom{0}{0}u^0 v^{0-0}\\ = u^0v^0 = uv \text{  by (i) of the recursive definition}$
#
# **$P(1):$ I do this for exercise only**
#
# $(uv)^{1}$ $= \sum_{m=0}^{1}\binom{1}{m}u^m v^{1-m}\\ = \binom{1}{0}u^0 v^{1-0} + \binom{1}{1}u^1 v^{1-1}\\ = u^0v^1 + v^1u^0\\ = uv^1 + v^1u \text{ - prove of (i)}$
#
# $P(n): \\
# (uv)^n = \sum_{m=0}^{n}\binom{n}{m}u^m v^{n-m} \text{ - assumed defined}$
#
# **$P(n+1):$ to be proved**
#
# $(uv)^{n+1} = ((uv)^{n})^1$
#
# $\frac{d}{dx}(uv)^{n}$ $= \frac{d}{dx}(\sum_{m=0}^{n}\binom{n}{m}(u^m v^{n-m})) \text{ differentiating wrt x}\\
# =\sum_{m=0}^{n}\binom{n}{m}\frac{d}{dx}(u^m v^{n-m}) \text{ -- * --}\\
# =\sum_{m=0}^{n}\binom{n}{m}(u^m (v^{n-m})^1 + (u^m)^1 v^{n-m}) \text{ -- ** -- (product rule)}\\
# =\sum_{m=0}^{n}\binom{n}{m}(u^m (v^{n-m+1}) + (u^{m+1}) v^{n-m})\\
# =\sum_{m=0}^{n}\binom{n}{m}u^m (v^{n+1-m}) + \sum_{m=0}^{n}\binom{n}{m}(u^{m+1}) v^{n-m}$
#
# $\binom{n+1}{m} = \binom{n}{m} + \binom{n}{m-1}\\
# \binom{n}{n} = \binom{n+1}{m} - \binom{n}{m-1}\\
# (x + y)^n = \sum_{m=0}^{n}\binom{n}{m}u^m v^{n-m} \text{ binomial theorem}$
#
#
# ### A second form of induction (strong induction)
#
# **Theorem 4.24 (Principle of mathematical induction—second form)**. Let $P(k)$ be a statement depending on a variable $k \in N$. In order to prove the statement "$P(k)$ is true for all $k \in N$" it is sufficient to prove:
#
# (i) $P(1)$ is true;
#
# (ii) if $P(j)$ is true for all integers $j$ such that $1 \le j \le n$, then $P(n + 1)$ is true.
#
# **Project 4.25 (Principle of mathematical induction—second form revisited)**. State and prove the analogue of Theorem 2.25 for this second form of induction.
#
# **Prove the statement "$P(j)$ is true for all integers $j$ such that $1 \le j \le k$" by induction on $k$
#
# **Solution**
#
# $P(k)$:
#
# **Project 4.26**. A sequence $(x_j)_{j=0}^{\infty}$ satisfies
#
# $x_1 = 1$ and for all $m \ge n \ge 0; x_{m+n} + x_{m−n} = \frac{1}{2}(x_2m + x_2n)$
#
# Find a formula for $x_j$. Prove that your formula is correct.
#
# Try to proof the following propositions about fibonacci sequence.
#
# $f_n = f_{n-1} + f_{n-2}$
#
# **Proposition 4.30**. For all $k, m \in N$, where $m \ge 2$,
#
# $f_{m+k} = f_{m-1}f_{k} + f_{m}f_{k+1}$
#
# **Proposition 4.31**. For all $k \in N$,
#
# $f_{2k+1} = f_{k}^{2} + f_{k+1}^{2}$
#
# **Proposition 4.32**. For all $k, m \in N, f_{mk} \text{ is divisible by } f_m$.
#
# **Project 4.33**. How many ways are there to order the numbers $1, 2, \dots, 20$ in a row so that the first number is $1$, the last number is $20$, and each pair of consecutive numbers differ by at most 2?
#
# **Solution**
#
# $f_1 = 1; f_n = 20; f_m = f_{m-1} + 2$
#
# $\dots$
#
#
# ## Chapter 5 to
#
# ### Underlying Notions in Set Theory
#
# **Proposition 5.1**. Let A;B;C be sets.
#
# (i) $A \subseteq A$.
#
# (ii) If $A \subseteq B$ and $B \subseteq C$ then $A \subseteq C$.
#
# **Proposition 5.2**. $\{7m+ 1 : m \in Z\} = \{7n− 6 : n \in Z\}$
#
# **Template for proving $ = B$**. Prove that $A \subseteq B$ and $B \subseteq A$.
#
# **Project 5.3**. Define the following sets:
#
# $
# \text{A } := \{3x : x \in N\}\\
# \text{B } := \{3x+ 21 : x \in N\}\\
# \text{C } := \{x+ 7 : x \in N\}\\
# \text{D } := \{3x : x \in N \text{ and } x > 7\}\\
# \text{E } := \{x : x \in N\}\\
# \text{F } := \{3x− 21 : x \in N\}\\
# \text{G } := \{x : x \in N \text{ and } x > 7\}
# $
#
# Determine which of the following set equalities are true. If a statement is true, prove it. If it is false, explain why this set equality does not hold.
#
# $
# \text{(i) } D = E\\
# \text{(ii) } C = G\\
# \text{(iii) } D = B
# $
#
# **Proposition 5.4**. Let A, B, C be sets.
#
# $
# \text{(i) } A = A\\
# \text{(i) If } A = B \text{ then } B = A\\
# \text{(i) If } A = B \text{ and } B = C \text{ then } A = C
# $
